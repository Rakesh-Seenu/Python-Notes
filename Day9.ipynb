# %% [markdown]
# # Dictionaries and nesting

# %% [markdown]
# {"key":"value"}

# %%
programming_dictionary = {
    "Bug": "An error in a program that prevents the program from running as expected.",
    "Variable": "A value that can be changed by the program.",
    "Function": "A piece of code that you can easily call over and over again."
}
#Retrieving items from dictionary.

# %%
print(programming_dictionary["Bug"])
# Out:
# An error in a program that prevents the program from running as expected.

# %%
print(programming_dictionary["Variable"])
# Out:
# A value that can be changed by the program.

# %%
programming_dictionary["loop"] = "A piece of code that you can easily call over and over again."
print(programming_dictionary)
# Out:
# {'Bug': 'An error in a program that prevents the program from running as expected.', 'Variable': 'A value that can be changed by the program.', 'Function': 'A piece of code that you can easily call over and over again.', 'loop': 'A piece of code that you can easily call over and over again.'}

# %%
programming_dictionary["Bug"]="How to fix a bug"
print(programming_dictionary)
# Out:
# {'Bug': 'How to fix a bug', 'Variable': 'A value that can be changed by the program.', 'Function': 'A piece of code that you can easily call over and over again.', 'loop': 'A piece of code that you can easily call over and over again.'}

# %%
for x in programming_dictionary:
    print(x)
    print(programming_dictionary[x])
# Out:
# Bug
# How to fix a bug
# Variable
# A value that can be changed by the program.
# Function
# A piece of code that you can easily call over and over again.
# loop
# A piece of code that you can easily call over and over again.

# %%
student_scores = {
    'Harry': 88,
    'Ron': 78,
    'Hermione': 95,
    'Draco': 75,
    'Neville': 60
}

print(student_scores)
 
# Create an empty dictionary to collect the new values.
student_grades = {}
 
# Loop through each key in the student_scores dictionary
for student in student_scores:
 
    #Get the value (student score) by using the key each time.
    score = student_scores[student]
 
    #Check what grade the score would get, then add it to student_grades
    if score >= 91:
        student_grades[student] = 'Outstanding'
    elif score >= 81:
        student_grades[student] = 'Exceeds Expectations'
    elif score >= 71:
        student_grades[student] = 'Acceptable'
    else:
        student_grades[student] = 'Fail'

print(student_grades)
# Out:
# {'Harry': 88, 'Ron': 78, 'Hermione': 95, 'Draco': 75, 'Neville': 60}
# {'Harry': 'Exceeds Expectations', 'Ron': 'Acceptable', 'Hermione': 'Outstanding', 'Draco': 'Acceptable', 'Neville': 'Fail'}

# %%
capitals = {
    "France": "Paris",
    "Germany": "Berlin"
}

travel_log = {
    "France": ["Paris", "Lille", "Dijon"],
    "Germany": ["Berlin", "Hamburg", "Cologne"]
}

print(travel_log["France"][1])

nested_dictionary = {    
    "France": {"cities_visited": ["Paris", "Lille", "Dijon"], "total_visits": 12},
    "Germany": {"cities_visited": ["Berlin", "Hamburg", "Stuttgart"], "total_visits": 5},
}
# Out:
# Lille

# %%
print(nested_dictionary["France"]["cities_visited"][0])
# Out:
# Paris

# %%
nested_dictionary["France"]["total_visits"] = 15
print(nested_dictionary)
# Out:
# {'France': {'cities_visited': ['Paris', 'Lille', 'Dijon'], 'total_visits': 15}, 'Germany': {'cities_visited': ['Berlin', 'Hamburg', 'Stuttgart'], 'total_visits': 5}}

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#blind auction program
bids = {}
bidding_finished = False
while not bidding_finished:
    name = input("What is your name?")
    price = int(input("What is your bid? $"))
    bids[name] = price
    should_continue = input("Are there any other bidders? Type 'yes' or 'no'")
    if should_continue == "no":
        bidding_finished = True
        highest_bid = 0
        winner = ""
        for bidder in bids:
            bid_amount = bids[bidder]
            if bid_amount > highest_bid:
                highest_bid = bid_amount
                winner = bidder
        print(f"The winner is {winner} with a bid of ${highest_bid}")
# Out:
# The winner is yogi with a bid of $60
